# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishanu2006/deep-learning/blob/main/using_pretrained_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')
# Out:
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step

# %%
img_path = '/content/tomato.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n07720875', 'bell_pepper', np.float32(0.3266488)), ('n12620546', 'hip', np.float32(0.121546604)), ('n07768694', 'pomegranate', np.float32(0.086195946))]

# %%
img_path2 = '/content/dog.jpg'
img2 = image.load_img(img_path2, target_size=(224, 224))
x2 = image.img_to_array(img2)
x2 = np.expand_dims(x2, axis=0)
x2 = preprocess_input(x2)

# %%
pred2 = model.predict(x2)
print('Predicted:', decode_predictions(pred2, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# Predicted: [('n02113799', 'standard_poodle', np.float32(0.88392395)), ('n02113712', 'miniature_poodle', np.float32(0.06869477)), ('n02093647', 'Bedlington_terrier', np.float32(0.018201226))]

# %%
img_path3 = '/content/chair.jpg'
img3 = image.load_img(img_path3, target_size=(224, 224))
x3 = image.img_to_array(img3)
x3 = np.expand_dims(x3, axis=0)
x3 = preprocess_input(x3)

# %%
pred3 = model.predict(x3)
print('Predicted: ',decode_predictions(pred3, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# Predicted:  [('n04099969', 'rocking_chair', np.float32(0.6478461)), ('n03376595', 'folding_chair', np.float32(0.08515098)), ('n03201208', 'dining_table', np.float32(0.07924797))]

# %%
img_path4 = '/content/bread.jpg'
img4 = image.load_img(img_path4, target_size=(224, 224))
x4 = image.img_to_array(img4)
x4 = np.expand_dims(x4, axis=0)
x4 = preprocess_input(x4)

# %%
pred4 = model.predict(x4)
print('Predicted: ',decode_predictions(pred4, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# Predicted:  [('n07684084', 'French_loaf', np.float32(0.95783544)), ('n02776631', 'bakery', np.float32(0.013253876)), ('n07614500', 'ice_cream', np.float32(0.004067858))]
